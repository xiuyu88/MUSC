# %%
import os
from enum import Enum

# %%
source = './data/mvtec_anomaly_detection/'
_CLASSNAMES = ["bottle", "cable", "capsule", "carpet", "grid",
            "hazelnut", "leather", "metal_nut", "pill", "screw",
            "tile", "toothbrush", "transistor", "wood", "zipper"]
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

# %%
imgpaths_per_class = {}
maskpaths_per_class = {}

# %%
classname =  "bottle"

# %%
classnames_to_use = [classname] if classname is not None else _CLASSNAMES

# %%
classnames_to_use
# Out:
# ['bottle']

# %%
class DatasetSplit(Enum):
    TRAIN = "train"
    VAL = "val"
    TEST = "test"

# %%
split=DatasetSplit.TRAIN

# %%
classpath = os.path.join(source, classname, split.value)
maskpath = os.path.join(source, classname, "ground_truth")
anomaly_types = os.listdir(classpath)

imgpaths_per_class[classname] = {}
maskpaths_per_class[classname] = {}

# %%
classpath, maskpath, anomaly_types
# Out:
# ('./data/mvtec_anomaly_detection/bottle\\train',
#  './data/mvtec_anomaly_detection/bottle\\ground_truth',
#  ['good'])

# %%
for anomaly in anomaly_types:
                anomaly_path = os.path.join(classpath, anomaly)
                anomaly_files = sorted(os.listdir(anomaly_path))
                imgpaths_per_class[classname][anomaly] = [
                    os.path.join(anomaly_path, x) for x in anomaly_files
                ]

                if split == DatasetSplit.TEST and anomaly != "good":
                    anomaly_mask_path = os.path.join(maskpath, anomaly)
                    anomaly_mask_files = sorted(os.listdir(anomaly_mask_path))
                    maskpaths_per_class[classname][anomaly] = [
                        os.path.join(anomaly_mask_path, x) for x in anomaly_mask_files
                    ]
                else:
                    maskpaths_per_class[classname]["good"] = None

# %%
imgpaths_per_class[classname], maskpaths_per_class[classname]
# Out:
# ({'good': ['./data/mvtec_anomaly_detection/bottle\\train\\good\\000.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\001.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\002.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\003.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\004.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\005.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\006.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\007.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\008.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\009.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\010.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\011.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\012.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\013.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\014.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\015.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\016.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\017.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\018.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\019.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\020.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\021.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\022.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\023.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\024.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\025.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\026.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\027.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\028.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\029.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\030.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\031.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\032.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\033.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\034.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\035.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\036.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\037.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\038.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\039.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\040.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\041.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\042.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\043.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\044.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\045.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\046.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\047.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\048.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\049.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\050.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\051.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\052.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\053.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\054.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\055.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\056.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\057.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\058.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\059.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\060.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\061.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\062.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\063.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\064.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\065.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\066.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\067.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\068.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\069.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\070.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\071.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\072.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\073.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\074.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\075.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\076.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\077.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\078.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\079.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\080.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\081.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\082.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\083.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\084.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\085.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\086.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\087.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\088.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\089.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\090.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\091.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\092.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\093.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\094.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\095.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\096.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\097.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\098.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\099.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\100.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\101.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\102.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\103.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\104.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\105.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\106.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\107.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\108.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\109.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\110.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\111.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\112.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\113.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\114.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\115.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\116.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\117.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\118.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\119.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\120.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\121.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\122.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\123.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\124.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\125.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\126.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\127.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\128.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\129.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\130.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\131.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\132.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\133.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\134.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\135.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\136.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\137.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\138.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\139.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\140.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\141.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\142.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\143.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\144.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\145.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\146.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\147.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\148.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\149.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\150.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\151.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\152.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\153.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\154.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\155.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\156.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\157.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\158.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\159.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\160.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\161.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\162.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\163.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\164.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\165.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\166.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\167.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\168.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\169.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\170.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\171.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\172.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\173.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\174.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\175.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\176.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\177.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\178.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\179.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\180.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\181.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\182.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\183.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\184.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\185.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\186.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\187.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\188.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\189.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\190.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\191.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\192.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\193.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\194.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\195.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\196.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\197.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\198.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\199.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\200.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\201.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\202.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\203.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\204.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\205.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\206.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\207.png',
#    './data/mvtec_anomaly_detection/bottle\\train\\good\\208.png']},
#  {'good': None})

# %%
data_to_iterate = []
for classname in sorted(imgpaths_per_class.keys()):
    for anomaly in sorted(imgpaths_per_class[classname].keys()):
        for i, image_path in enumerate(imgpaths_per_class[classname][anomaly]):
            data_tuple = [classname, anomaly, image_path]
            if split == DatasetSplit.TEST and anomaly != "good":
                data_tuple.append(maskpaths_per_class[classname][anomaly][i])
            else:
                data_tuple.append(None)
            data_to_iterate.append(data_tuple)

# %%
data_to_iterate
# Out:
# [['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\000.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\001.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\002.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\003.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\004.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\005.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\006.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\007.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\008.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\009.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\010.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\011.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\012.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\013.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\014.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\015.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\016.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\017.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\018.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\019.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\020.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\021.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\022.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\023.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\024.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\025.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\026.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\027.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\028.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\029.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\030.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\031.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\032.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\033.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\034.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\035.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\036.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\037.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\038.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\039.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\040.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\041.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\042.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\043.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\044.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\045.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\046.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\047.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\048.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\049.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\050.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\051.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\052.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\053.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\054.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\055.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\056.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\057.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\058.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\059.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\060.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\061.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\062.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\063.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\064.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\065.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\066.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\067.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\068.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\069.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\070.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\071.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\072.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\073.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\074.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\075.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\076.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\077.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\078.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\079.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\080.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\081.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\082.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\083.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\084.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\085.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\086.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\087.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\088.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\089.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\090.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\091.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\092.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\093.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\094.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\095.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\096.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\097.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\098.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\099.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\100.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\101.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\102.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\103.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\104.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\105.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\106.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\107.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\108.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\109.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\110.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\111.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\112.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\113.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\114.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\115.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\116.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\117.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\118.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\119.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\120.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\121.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\122.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\123.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\124.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\125.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\126.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\127.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\128.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\129.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\130.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\131.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\132.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\133.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\134.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\135.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\136.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\137.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\138.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\139.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\140.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\141.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\142.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\143.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\144.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\145.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\146.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\147.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\148.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\149.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\150.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\151.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\152.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\153.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\154.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\155.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\156.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\157.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\158.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\159.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\160.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\161.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\162.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\163.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\164.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\165.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\166.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\167.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\168.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\169.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\170.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\171.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\172.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\173.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\174.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\175.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\176.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\177.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\178.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\179.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\180.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\181.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\182.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\183.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\184.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\185.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\186.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\187.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\188.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\189.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\190.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\191.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\192.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\193.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\194.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\195.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\196.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\197.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\198.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\199.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\200.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\201.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\202.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\203.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\204.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\205.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\206.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\207.png',
#   None],
#  ['bottle',
#   'good',
#   './data/mvtec_anomaly_detection/bottle\\train\\good\\208.png',
#   None]]
